# %%
import numpy as np
import pandas as pd
import seaborn as sns
import re
import string
import warnings
warnings.filterwarnings('ignore')
import librosa
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.layers import Dense, Conv1D, MaxPool1D, Dropout, Flatten
from tensorflow.keras.losses import sparse_categorical_crossentropy, categorical_crossentropy
import tensorflow as tf
from sklearn.metrics import classification_report



import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import train_test_split
# from sklearn.metrics import classification_report, roc_curve, accuracy_score, plot_confusion_matrix

import missingno as msno
from matplotlib import pyplot as plt

import imp
from nltk.util import ngrams
from gensim.models import Word2Vec
import multiprocessing
from time import time  # To time our operations


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,Flatten,LayerNormalization,BatchNormalization,Dropout,Conv1D,MaxPooling1D,GlobalMaxPooling1D,GlobalAveragePooling1D,Activation,Input,concatenate,Reshape



from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Conv1D, MaxPool1D, Dropout, Flatten
from tensorflow.keras.losses import sparse_categorical_crossentropy, categorical_crossentropy
import tensorflow as tf


from scipy import interpolate
import librosa

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

from tensorflow.keras.preprocessing.text import Tokenizer

import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier, NeighborhoodComponentsAnalysis
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import tensorflow as tf

import imp
from nltk.util import ngrams
from gensim.models import Word2Vec
import multiprocessing
from time import time  # To time our operations

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,Flatten,Permute

from sklearn.preprocessing import OneHotEncoder,LabelEncoder

# %%
df = pd.read_csv("C:/Users/dianu/OneDrive/Desktop/Final_results/dataset/categorical_data.csv")
df = df.drop_duplicates()
sns.set(rc={'figure.figsize':(28,8)})
sns.countplot(x="cyberbullying_type", data=df, order=df.cyberbullying_type.value_counts().index).set_title("Tweets distribution by cyberbullying types")
# Out:
# Text(0.5, 1.0, 'Tweets distribution by cyberbullying types')

# %%
classes=list(df["cyberbullying_type"].unique())
df_list=[]

flux=700-800
for i in range(len(classes)):
    sub_df=df[df["cyberbullying_type"]==classes[i]]
    #drop first 7000 rows of sub_df
    if (classes[i]=="other_cyberbullying"):
        sub_df=sub_df.drop(sub_df.index[:6870+flux])
    elif (classes[i]=="religion"):
        sub_df=sub_df.drop(sub_df.index[:7050+flux])
    elif (classes[i]=="age"):
        sub_df=sub_df.drop(sub_df.index[:7050+flux])       
    else:
        sub_df=sub_df.drop(sub_df.index[:7000+flux])
    df_list.append(sub_df)


#concatenate all sub_df
df_dropped=pd.concat(df_list)
df_drop=df_dropped.reset_index()


df = df_drop
sns.set(rc={'figure.figsize':(28,8)})
sns.countplot(x="cyberbullying_type", data=df, order=df.cyberbullying_type.value_counts().index).set_title("Tweets distribution by cyberbullying types")
# Out:
# Text(0.5, 1.0, 'Tweets distribution by cyberbullying types')

# %%
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dianu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dianu\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dianu\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\dianu\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
def initial_cleaning(text):
    text = re.sub(r"^RT[\s]+","",text)
    text = text.lower()
    text = re.sub(r"https?:\/\/.*[\r\n]*","https",text)
    text = re.sub(r"@[A-Za-z0-9]+","",text)
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002700-\U000027BF"  # Dingbats
        u"\U0001F600-\U0001F64F"  # Emoticons
        u"\U00002600-\U000026FF"  # Miscellaneous Symbols
        u"\U0001F300-\U0001F5FF"  # Miscellaneous Symbols And Pictographs
        u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        u"\U0001F680-\U0001F6FF"  # Transport and Map Symbols
                           "]+", flags=re.UNICODE)

    text=emoji_pattern.sub(r'', text)
    text = re.sub(r'[0-9]',' ',text) 
    text = re.compile('[%s]' % re.escape(string.punctuation)).sub(' ', text)
    text = re.sub('\s+', ' ', text)
    return text

def remove_stopword(text):
    a = [i for i in text.split() if i not in stopwords.words('english')]
    return ' '.join(a)

porter = PorterStemmer()
def stem(text):
    a = [porter.stem(i) for i in text.split()]
    return ' '.join(a)

porter = PorterStemmer()
def stem(text):
    a = [porter.stem(i) for i in text.split()]
    return ' '.join(a)

wl = WordNetLemmatizer()
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

tokenizer = TweetTokenizer(preserve_case=False, 
                           strip_handles=True,
                           reduce_len=True)
def lemmatizer(text):
    word_pos_tags = nltk.pos_tag(tokenizer.tokenize(text))
    a=[wl.lemmatize(tag[0], get_wordnet_pos(tag[1])) for idx, tag in enumerate(word_pos_tags)]
    return " ".join(a)



def text_preprocessing(text):
    return lemmatizer(stem(remove_stopword(initial_cleaning(text))))

df["original_tweet"] = df.tweet_text
df.tweet_text = df.tweet_text.apply(lambda x: text_preprocessing(x))
df
# Out:
#       index                                         tweet_text  \
# 0      6904                                      peopl lol mkr
# 1      6905                                huh might tri point
# 2      6906            yeah men never comment athlet bodi ever
# 3      6907                                             sociai
# 4      6908  would problem crimin decid enter school lunch ...
# ...     ...                                                ...
# 6281  47687  black ppl expect anyth depend anyth yet free p...
# 6282  47688  turner withhold disappoint turner call court “...
# 6283  47689  swear god dumb nigger bitch get bleach hair re...
# 6284  47690  yea fuck rt your nigger fuck unfollow fuck dum...
# 6285  47691  bro u gotta chill rt dog fuck kp dumb nigger b...
#
#      cyberbullying_type                                     original_tweet
# 0     not_cyberbullying                      Who are these people LOL #MKR
# 1     not_cyberbullying  @TURBOCUNT huh. i might have to try this at so...
# 2     not_cyberbullying  @johnnyrejection @espn Yeah, men never comment...
# 3     not_cyberbullying                                            sociais
# 4     not_cyberbullying  @JackBPR Which would not be a problem if a cri...
# ...                 ...                                                ...
# 6281          ethnicity  Black ppl aren't expected to do anything, depe...
# 6282          ethnicity  Turner did not withhold his disappointment. Tu...
# 6283          ethnicity  I swear to God. This dumb nigger bitch. I have...
# 6284          ethnicity  Yea fuck you RT @therealexel: IF YOURE A NIGGE...
# 6285          ethnicity  Bro. U gotta chill RT @CHILLShrammy: Dog FUCK ...
#
# [6286 rows x 4 columns]

# %%
text_list_p=df["tweet_text"].tolist()
labels_p=df["cyberbullying_type"].tolist()

text_list=[]
labels=[]
for i in range(len(labels_p)):
    if text_list_p[i]!='':
        text_list.append(text_list_p[i])
        labels.append(labels_p[i])

labels=np.array(labels)



label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(labels)
onehot_encoder = OneHotEncoder(sparse=False)
integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
num_classes=int(np.max(integer_encoded)+1)
onehot_encoded = onehot_encoder.fit_transform(integer_encoded)
mapping = dict(zip(label_encoder.classes_, onehot_encoder.transform(label_encoder.transform(label_encoder.classes_).reshape(num_classes, 1))))
for key,value in mapping.items():
    print("",key," ----------------------------- ",value)



# randomly create indices for train and test
indices = np.arange(len(text_list))
np.random.shuffle(indices)
splitter=0.8
train_indices = indices[:int(splitter*len(text_list))]
test_indices = indices[int(splitter*len(text_list)):]
text_list_train = np.array(text_list)[train_indices]
text_list_test = np.array(text_list)[test_indices]
labels_train = np.array(labels)[train_indices]
labels_test = np.array(labels)[test_indices]
onehot_encoded_train = np.array(onehot_encoded)[train_indices]
onehot_encoded_test = np.array(onehot_encoded)[test_indices]
integer_encoded_train = np.array(integer_encoded)[train_indices]
integer_encoded_test = np.array(integer_encoded)[test_indices]







# doing for text_list_train
omega_text_words_train = []
n=1
cores = multiprocessing.cpu_count() # Count the number of cores in a computer
for i in range(len(text_list_train)):
    sentence=text_list_train[i]
    unigrams = ngrams(sentence.split(), n)
    flat_list = [item for sublist in [list(a) for a in unigrams] for item in sublist]
    omega_text_words_train.append(flat_list)


# doing for text_list_test
omega_text_words_test = []
n=1
cores = multiprocessing.cpu_count() # Count the number of cores in a computer
for i in range(len(text_list_test)):
    sentence=text_list_test[i]
    unigrams = ngrams(sentence.split(), n)
    flat_list = [item for sublist in [list(a) for a in unigrams] for item in sublist]
    omega_text_words_test.append(flat_list)


# doing for text_list
omega_text_words = []
n=1
cores = multiprocessing.cpu_count() # Count the number of cores in a computer
for i in range(len(text_list)):
    sentence=text_list[i]
    unigrams = ngrams(sentence.split(), n)
    flat_list = [item for sublist in [list(a) for a in unigrams] for item in sublist]
    omega_text_words.append(flat_list)
# Out:
#  age  -----------------------------  [1. 0. 0. 0. 0. 0.]
#  ethnicity  -----------------------------  [0. 1. 0. 0. 0. 0.]
#  gender  -----------------------------  [0. 0. 1. 0. 0. 0.]
#  not_cyberbullying  -----------------------------  [0. 0. 0. 1. 0. 0.]
#  other_cyberbullying  -----------------------------  [0. 0. 0. 0. 1. 0.]
#  religion  -----------------------------  [0. 0. 0. 0. 0. 1.]

# %%
t = time()
w2v_model=Word2Vec(sentences=omega_text_words,vector_size=50,window=4,min_count=1,workers=cores-1,epochs=60,sg=1) #sh=1->Skip-gram,0->CBOW

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))

#As we do not plan to train the model any further, we are calling init_sims(), which will make the model much more memory-efficient:
w2v_model.init_sims(replace=True)
# Out:
# Time to train the model: 0.19 mins

# %%
# getting word2vec embedding for train
ref_embedding_train=np.zeros((len(integer_encoded_train),max([len(i) for i in omega_text_words_train]),50))
for i in range(ref_embedding_train.shape[0]):
    sent=omega_text_words_train[i]
    for j in range(len(sent)):
        ref_embedding_train[i,j,:]=w2v_model.wv[omega_text_words_train[i][j]]


# getting word2vec embedding for test
ref_embedding_test=np.zeros((len(integer_encoded_test),max([len(i) for i in omega_text_words_test]),50))
for i in range(ref_embedding_test.shape[0]):
    sent=omega_text_words_test[i]
    for j in range(len(sent)):
        ref_embedding_test[i,j,:]=w2v_model.wv[omega_text_words_test[i][j]]


plt.figure()
for i in range(len(ref_embedding_test)):
    plt.plot(ref_embedding_test[i,:,0])
    plt.title("Reference word2vec time series (First Component)")

# %%
print("Train Reduced Word Embeddings Shape: ",ref_embedding_train.shape)
print("Test Reduced Word Embeddings Shape: ",ref_embedding_test.shape)
# Out:
# Train Reduced Word Embeddings Shape:  (5017, 252, 50)
# Test Reduced Word Embeddings Shape:  (1255, 144, 50)

# %%
# pad ref_embedding_test to 252 with 0.0
if ref_embedding_train.shape[1]<ref_embedding_test.shape[1]:
    ref_embedding_train=ref_embedding_train[:,:ref_embedding_test.shape[1],:]
    ref_embedding_train_pad=np.zeros((ref_embedding_train.shape[0],ref_embedding_test.shape[1],ref_embedding_test.shape[2]))
    ref_embedding_train_pad[:ref_embedding_train.shape[0],:ref_embedding_train.shape[1],:ref_embedding_train.shape[2]]=ref_embedding_train
    ref_embedding_train=ref_embedding_train_pad

if ref_embedding_train.shape[1]>ref_embedding_test.shape[1]:
    ref_embedding_test_pad=np.zeros((ref_embedding_test.shape[0],ref_embedding_train.shape[1],ref_embedding_test.shape[2]))
    ref_embedding_test_pad[:ref_embedding_test.shape[0],:ref_embedding_test.shape[1],:ref_embedding_test.shape[2]]=ref_embedding_test
    ref_embedding_test=ref_embedding_test_pad

# %%
print("Train Reduced Word Embeddings Shape: ",ref_embedding_train.shape)
print("Test Reduced Word Embeddings Shape: ",ref_embedding_test.shape)
# Out:
# Train Reduced Word Embeddings Shape:  (5017, 252, 50)
# Test Reduced Word Embeddings Shape:  (1255, 252, 50)

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res


# define keras model
def create_model():
    inputs = layers.Input(shape=(252, 50))
    head_size = 25
    num_heads = 2
    ff_dim = 32
    num_transformer_blocks = 3
    dropout = 0.25

    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(20, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=keras.optimizers.Adam(lr=1e-3),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model


model = create_model()
model.summary()
model.fit(ref_embedding_train, onehot_encoded_train, epochs=20, verbose=2,validation_data=(ref_embedding_test,onehot_encoded_test))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 252, 50)]    0           []
#
#  layer_normalization (LayerNorm  (None, 252, 50)     100         ['input_1[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 252, 50)     10200       ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  dropout (Dropout)              (None, 252, 50)      0           ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 252, 50)     0           ['dropout[0][0]',
#  da)                                                              'input_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 252, 50)     100         ['tf.__operators__.add[0][0]']
#  rmalization)
#
#  conv1d (Conv1D)                (None, 252, 32)      1632        ['layer_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 252, 32)      0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 252, 50)      1650        ['dropout_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 252, 50)     0           ['conv1d_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 252, 50)     100         ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 252, 50)     10200       ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 252, 50)      0           ['multi_head_attention_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 252, 50)     0           ['dropout_2[0][0]',
#  mbda)                                                            'tf.__operators__.add_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 252, 50)     100         ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  conv1d_2 (Conv1D)              (None, 252, 32)      1632        ['layer_normalization_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 252, 32)      0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 252, 50)      1650        ['dropout_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 252, 50)     0           ['conv1d_3[0][0]',
#  mbda)                                                            'tf.__operators__.add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 252, 50)     100         ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 252, 50)     10200       ['layer_normalization_4[0][0]',
#  eadAttention)                                                    'layer_normalization_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 252, 50)      0           ['multi_head_attention_2[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 252, 50)     0           ['dropout_4[0][0]',
#  mbda)                                                            'tf.__operators__.add_3[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 252, 50)     100         ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  conv1d_4 (Conv1D)              (None, 252, 32)      1632        ['layer_normalization_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 252, 32)      0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 252, 50)      1650        ['dropout_5[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 252, 50)     0           ['conv1d_5[0][0]',
#  mbda)                                                            'tf.__operators__.add_4[0][0]']
#
#  global_average_pooling1d (Glob  (None, 50)          0           ['tf.__operators__.add_5[0][0]']
#  alAveragePooling1D)
#
#  dropout_6 (Dropout)            (None, 50)           0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 20)           1020        ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)            (None, 20)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 6)            126         ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 42,192
# Trainable params: 42,192
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/20
# 157/157 - 21s - loss: 1.2010 - accuracy: 0.4945 - val_loss: 0.6707 - val_accuracy: 0.7386 - 21s/epoch - 133ms/step
# Epoch 2/20
# 157/157 - 7s - loss: 0.7208 - accuracy: 0.7008 - val_loss: 0.5832 - val_accuracy: 0.7498 - 7s/epoch - 47ms/step
# Epoch 3/20
# 157/157 - 7s - loss: 0.6232 - accuracy: 0.7502 - val_loss: 0.5617 - val_accuracy: 0.7546 - 7s/epoch - 47ms/step
# Epoch 4/20
# 157/157 - 11s - loss: 0.5950 - accuracy: 0.7453 - val_loss: 0.5282 - val_accuracy: 0.7522 - 11s/epoch - 71ms/step
# Epoch 5/20
# 157/157 - 53s - loss: 0.5727 - accuracy: 0.7512 - val_loss: 0.5747 - val_accuracy: 0.7729 - 53s/epoch - 335ms/step
# Epoch 6/20
# 157/157 - 3s - loss: 0.5592 - accuracy: 0.7666 - val_loss: 0.6289 - val_accuracy: 0.7841 - 3s/epoch - 19ms/step
# Epoch 7/20
# 157/157 - 3s - loss: 0.5468 - accuracy: 0.7726 - val_loss: 0.5991 - val_accuracy: 0.7896 - 3s/epoch - 19ms/step
# Epoch 8/20
# 157/157 - 3s - loss: 0.5273 - accuracy: 0.7847 - val_loss: 0.5474 - val_accuracy: 0.7841 - 3s/epoch - 18ms/step
# Epoch 9/20
# 157/157 - 3s - loss: 0.5248 - accuracy: 0.7774 - val_loss: 0.5339 - val_accuracy: 0.7849 - 3s/epoch - 18ms/step
# Epoch 10/20
# 157/157 - 3s - loss: 0.5112 - accuracy: 0.7839 - val_loss: 0.5815 - val_accuracy: 0.7849 - 3s/epoch - 19ms/step
# Epoch 11/20
# 157/157 - 3s - loss: 0.5009 - accuracy: 0.8011 - val_loss: 0.5351 - val_accuracy: 0.7920 - 3s/epoch - 18ms/step
# Epoch 12/20
# 157/157 - 3s - loss: 0.5006 - accuracy: 0.7965 - val_loss: 0.5257 - val_accuracy: 0.7857 - 3s/epoch - 18ms/step
# Epoch 13/20
# 157/157 - 3s - loss: 0.4853 - accuracy: 0.8009 - val_loss: 0.5447 - val_accuracy: 0.7968 - 3s/epoch - 18ms/step
# Epoch 14/20
# 157/157 - 3s - loss: 0.4765 - accuracy: 0.8059 - val_loss: 0.5436 - val_accuracy: 0.7992 - 3s/epoch - 20ms/step
# Epoch 15/20
# 157/157 - 4s - loss: 0.4786 - accuracy: 0.8063 - val_loss: 0.5465 - val_accuracy: 0.7976 - 4s/epoch - 24ms/step
# Epoch 16/20
# 157/157 - 3s - loss: 0.4668 - accuracy: 0.8069 - val_loss: 0.5540 - val_accuracy: 0.7984 - 3s/epoch - 20ms/step
# Epoch 17/20
# 157/157 - 3s - loss: 0.4570 - accuracy: 0.8075 - val_loss: 0.5151 - val_accuracy: 0.8056 - 3s/epoch - 20ms/step
# Epoch 18/20
# 157/157 - 3s - loss: 0.4506 - accuracy: 0.8134 - val_loss: 0.6438 - val_accuracy: 0.7729 - 3s/epoch - 22ms/step
# Epoch 19/20
# 157/157 - 4s - loss: 0.4524 - accuracy: 0.8104 - val_loss: 0.5757 - val_accuracy: 0.8024 - 4s/epoch - 25ms/step
# Epoch 20/20
# 157/157 - 3s - loss: 0.4444 - accuracy: 0.8194 - val_loss: 0.6067 - val_accuracy: 0.7833 - 3s/epoch - 19ms/step

# %%
ref=np.argmax(onehot_encoded_test,axis=1)
predictions=np.argmax(model.predict(ref_embedding_test),axis=1)
cm=confusion_matrix(ref,predictions)


label_names=[]
for key,_ in mapping.items():
    label_names.append(key)

    
#plot confusion matrix

df_cm = pd.DataFrame(cm, label_names,label_names)
plt.figure(figsize = (10,7),dpi=200)
sn.set(font_scale=1.8)  # Increase the font size for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16},fmt='d') # font size
# Out:
# 40/40 [==============================] - 1s 6ms/step
# <Axes: >

# %%
print(classification_report(ref, predictions,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8844    0.9803    0.9299       203
#            1     1.0000    0.9670    0.9832       212
#            2     0.9111    0.7421    0.8180       221
#            3     0.4805    0.5857    0.5279       210
#            4     0.5367    0.4750    0.5040       200
#            5     0.9292    0.9426    0.9359       209
#
#     accuracy                         0.7833      1255
#    macro avg     0.7903    0.7821    0.7831      1255
# weighted avg     0.7931    0.7833    0.7850      1255
